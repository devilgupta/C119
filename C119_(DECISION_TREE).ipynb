# %% [markdown]
# <a href="https://colab.research.google.com/github/devilgupta/C119/blob/main/C119_(DECISION_TREE).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-43f3ff31-e1d8-4c70-84f9-b2e0f7580343" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-43f3ff31-e1d8-4c70-84f9-b2e0f7580343">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving C119.csv to C119.csv

# %%
import pandas as pd
columnames=["Pregnant","Glucose","BP","Skin","Insulin","BMI","Pedigree","Age","Label"]
df=pd.read_csv("C119.csv",names=columnames).iloc[1:]
print(df.head())
# Out:
#   Pregnant Glucose  BP Skin Insulin   BMI Pedigree Age Label
# 1        6     148  72   35       0  33.6    0.627  50     1
# 2        1      85  66   29       0  26.6    0.351  31     0
# 3        8     183  64    0       0  23.3    0.672  32     1
# 4        1      89  66   23      94  28.1    0.167  21     0
# 5        0     137  40   35     168  43.1    2.288  33     1

# %%
features=["Pregnant","Glucose","BP","Skin","Insulin","BMI","Pedigree","Age"]
X=df[features]
y=df.Label

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=1)
clf=DecisionTreeClassifier()
clf=clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test,y_pred)*100)
# Out:
# Accuracy: 67.53246753246754

# %%
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO
from IPython.display import Image
import pydotplus
dot_data=StringIO()
export_graphviz(clf,out_file=dot_data,filled=True,rounded=True,special_characters=True,feature_names=features,class_names=['0','1'])
print(dot_data.getvalue())
# Out:
# digraph Tree {
# node [shape=box, style="filled, rounded", color="black", fontname=helvetica] ;
# edge [fontname=helvetica] ;
# 0 [label=<Glucose &le; 129.5<br/>gini = 0.449<br/>samples = 537<br/>value = [354, 183]<br/>class = 0>, fillcolor="#f2c29f"] ;
# 1 [label=<BMI &le; 26.3<br/>gini = 0.329<br/>samples = 357<br/>value = [283, 74]<br/>class = 0>, fillcolor="#eca26d"] ;
# 0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;
# 2 [label=<BMI &le; 9.1<br/>gini = 0.06<br/>samples = 97<br/>value = [94, 3]<br/>class = 0>, fillcolor="#e6853f"] ;
# 1 -> 2 ;
# 3 [label=<Glucose &le; 114.5<br/>gini = 0.444<br/>samples = 6<br/>value = [4, 2]<br/>class = 0>, fillcolor="#f2c09c"] ;
# 2 -> 3 ;
# 4 [label=<gini = 0.0<br/>samples = 4<br/>value = [4, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 3 -> 4 ;
# 5 [label=<gini = 0.0<br/>samples = 2<br/>value = [0, 2]<br/>class = 1>, fillcolor="#399de5"] ;
# 3 -> 5 ;
# 6 [label=<Pedigree &le; 0.669<br/>gini = 0.022<br/>samples = 91<br/>value = [90, 1]<br/>class = 0>, fillcolor="#e5823b"] ;
# 2 -> 6 ;
# 7 [label=<gini = 0.0<br/>samples = 76<br/>value = [76, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 6 -> 7 ;
# 8 [label=<Pedigree &le; 0.705<br/>gini = 0.124<br/>samples = 15<br/>value = [14, 1]<br/>class = 0>, fillcolor="#e78a47"] ;
# 6 -> 8 ;
# 9 [label=<gini = 0.0<br/>samples = 1<br/>value = [0, 1]<br/>class = 1>, fillcolor="#399de5"] ;
# 8 -> 9 ;
# 10 [label=<gini = 0.0<br/>samples = 14<br/>value = [14, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 8 -> 10 ;
# 11 [label=<Age &le; 27.5<br/>gini = 0.397<br/>samples = 260<br/>value = [189, 71]<br/>class = 0>, fillcolor="#efb083"] ;
# 1 -> 11 ;
# 12 [label=<BMI &le; 45.4<br/>gini = 0.243<br/>samples = 120<br/>value = [103, 17]<br/>class = 0>, fillcolor="#e9965a"] ;
# 11 -> 12 ;
# 13 [label=<Pregnant &le; 7.0<br/>gini = 0.212<br/>samples = 116<br/>value = [102, 14]<br/>class = 0>, fillcolor="#e99254"] ;
# 12 -> 13 ;
# 14 [label=<BP &le; 12.0<br/>gini = 0.201<br/>samples = 115<br/>value = [102, 13]<br/>class = 0>, fillcolor="#e89152"] ;
# 13 -> 14 ;
# 15 [label=<gini = 0.0<br/>samples = 1<br/>value = [0, 1]<br/>class = 1>, fillcolor="#399de5"] ;
# 14 -> 15 ;
# 16 [label=<Pedigree &le; 1.272<br/>gini = 0.188<br/>samples = 114<br/>value = [102, 12]<br/>class = 0>, fillcolor="#e89050"] ;
# 14 -> 16 ;
# 17 [label=<BMI &le; 30.95<br/>gini = 0.165<br/>samples = 110<br/>value = [100, 10]<br/>class = 0>, fillcolor="#e88e4d"] ;
# 16 -> 17 ;
# 18 [label=<gini = 0.0<br/>samples = 43<br/>value = [43, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 17 -> 18 ;
# 19 [label=<BP &le; 53.0<br/>gini = 0.254<br/>samples = 67<br/>value = [57, 10]<br/>class = 0>, fillcolor="#ea975c"] ;
# 17 -> 19 ;
# 20 [label=<Pedigree &le; 0.264<br/>gini = 0.5<br/>samples = 6<br/>value = [3, 3]<br/>class = 0>, fillcolor="#ffffff"] ;
# 19 -> 20 ;
# 21 [label=<gini = 0.0<br/>samples = 2<br/>value = [0, 2]<br/>class = 1>, fillcolor="#399de5"] ;
# 20 -> 21 ;
# 22 [label=<Insulin &le; 179.5<br/>gini = 0.375<br/>samples = 4<br/>value = [3, 1]<br/>class = 0>, fillcolor="#eeab7b"] ;
# 20 -> 22 ;
# 23 [label=<gini = 0.0<br/>samples = 3<br/>value = [3, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 22 -> 23 ;
# 24 [label=<gini = 0.0<br/>samples = 1<br/>value = [0, 1]<br/>class = 1>, fillcolor="#399de5"] ;
# 22 -> 24 ;
# 25 [label=<Pedigree &le; 0.652<br/>gini = 0.203<br/>samples = 61<br/>value = [54, 7]<br/>class = 0>, fillcolor="#e89153"] ;
# 19 -> 25 ;
# 26 [label=<Insulin &le; 36.5<br/>gini = 0.15<br/>samples = 49<br/>value = [45, 4]<br/>class = 0>, fillcolor="#e78c4b"] ;
# 25 -> 26 ;
# 27 [label=<BP &le; 82.5<br/>gini = 0.32<br/>samples = 20<br/>value = [16, 4]<br/>class = 0>, fillcolor="#eca06a"] ;
# 26 -> 27 ;
# 28 [label=<Skin &le; 40.5<br/>gini = 0.266<br/>samples = 19<br/>value = [16, 3]<br/>class = 0>, fillcolor="#ea995e"] ;
# 27 -> 28 ;
# 29 [label=<BMI &le; 33.65<br/>gini = 0.198<br/>samples = 18<br/>value = [16, 2]<br/>class = 0>, fillcolor="#e89152"] ;
# 28 -> 29 ;
# 30 [label=<Glucose &le; 102.0<br/>gini = 0.444<br/>samples = 6<br/>value = [4, 2]<br/>class = 0>, fillcolor="#f2c09c"] ;
# 29 -> 30 ;
# 31 [label=<gini = 0.0<br/>samples = 3<br/>value = [3, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 30 -> 31 ;
# 32 [label=<Glucose &le; 119.0<br/>gini = 0.444<br/>samples = 3<br/>value = [1, 2]<br/>class = 1>, fillcolor="#9ccef2"] ;
# 30 -> 32 ;
# 33 [label=<gini = 0.0<br/>samples = 2<br/>value = [0, 2]<br/>class = 1>, fillcolor="#399de5"] ;
# 32 -> 33 ;
# 34 [label=<gini = 0.0<br/>samples = 1<br/>value = [1, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 32 -> 34 ;
# 35 [label=<gini = 0.0<br/>samples = 12<br/>value = [12, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 29 -> 35 ;
# 36 [label=<gini = 0.0<br/>samples = 1<br/>value = [0, 1]<br/>class = 1>, fillcolor="#399de5"] ;
# 28 -> 36 ;
# 37 [label=<gini = 0.0<br/>samples = 1<br/>value = [0, 1]<br/>class = 1>, fillcolor="#399de5"] ;
# 27 -> 37 ;
# 38 [label=<gini = 0.0<br/>samples = 29<br/>value = [29, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 26 -> 38 ;
# 39 [label=<Insulin &le; 65.5<br/>gini = 0.375<br/>samples = 12<br/>value = [9, 3]<br/>class = 0>, fillcolor="#eeab7b"] ;
# 25 -> 39 ;
# 40 [label=<gini = 0.0<br/>samples = 7<br/>value = [7, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 39 -> 40 ;
# 41 [label=<BP &le; 67.0<br/>gini = 0.48<br/>samples = 5<br/>value = [2, 3]<br/>class = 1>, fillcolor="#bddef6"] ;
# 39 -> 41 ;
# 42 [label=<gini = 0.0<br/>samples = 3<br/>value = [0, 3]<br/>class = 1>, fillcolor="#399de5"] ;
# 41 -> 42 ;
# 43 [label=<gini = 0.0<br/>samples = 2<br/>value = [2, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 41 -> 43 ;
# 44 [label=<Pedigree &le; 1.496<br/>gini = 0.5<br/>samples = 4<br/>value = [2, 2]<br/>class = 0>, fillcolor="#ffffff"] ;
# 16 -> 44 ;
# 45 [label=<gini = 0.0<br/>samples = 2<br/>value = [0, 2]<br/>class = 1>, fillcolor="#399de5"] ;
# 44 -> 45 ;
# 46 [label=<gini = 0.0<br/>samples = 2<br/>value = [2, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 44 -> 46 ;
# 47 [label=<gini = 0.0<br/>samples = 1<br/>value = [0, 1]<br/>class = 1>, fillcolor="#399de5"] ;
# 13 -> 47 ;
# 48 [label=<Insulin &le; 185.0<br/>gini = 0.375<br/>samples = 4<br/>value = [1, 3]<br/>class = 1>, fillcolor="#7bbeee"] ;
# 12 -> 48 ;
# 49 [label=<gini = 0.0<br/>samples = 3<br/>value = [0, 3]<br/>class = 1>, fillcolor="#399de5"] ;
# 48 -> 49 ;
# 50 [label=<gini = 0.0<br/>samples = 1<br/>value = [1, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 48 -> 50 ;
# 51 [label=<Pedigree &le; 0.563<br/>gini = 0.474<br/>samples = 140<br/>value = [86, 54]<br/>class = 0>, fillcolor="#f5d0b5"] ;
# 11 -> 51 ;
# 52 [label=<Glucose &le; 101.5<br/>gini = 0.408<br/>samples = 98<br/>value = [70, 28]<br/>class = 0>, fillcolor="#efb388"] ;
# 51 -> 52 ;
# 53 [label=<BP &le; 27.0<br/>gini = 0.208<br/>samples = 34<br/>value = [30, 4]<br/>class = 0>, fillcolor="#e89253"] ;
# 52 -> 53 ;
# 54 [label=<gini = 0.0<br/>samples = 1<br/>value = [0, 1]<br/>class = 1>, fillcolor="#399de5"] ;
# 53 -> 54 ;
# 55 [label=<Age &le; 42.5<br/>gini = 0.165<br/>samples = 33<br/>value = [30, 3]<br/>class = 0>, fillcolor="#e88e4d"] ;
# 53 -> 55 ;
# 56 [label=<gini = 0.0<br/>samples = 23<br/>value = [23, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 55 -> 56 ;
# 57 [label=<Glucose &le; 97.5<br/>gini = 0.42<br/>samples = 10<br/>value = [7, 3]<br/>class = 0>, fillcolor="#f0b78e"] ;
# 55 -> 57 ;
# 58 [label=<Skin &le; 24.0<br/>gini = 0.5<br/>samples = 6<br/>value = [3, 3]<br/>class = 0>, fillcolor="#ffffff"] ;
# 57 -> 58 ;
# 59 [label=<gini = 0.0<br/>samples = 3<br/>value = [3, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 58 -> 59 ;
# 60 [label=<gini = 0.0<br/>samples = 3<br/>value = [0, 3]<br/>class = 1>, fillcolor="#399de5"] ;
# 58 -> 60 ;
# 61 [label=<gini = 0.0<br/>samples = 4<br/>value = [4, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 57 -> 61 ;
# 62 [label=<BP &le; 67.0<br/>gini = 0.469<br/>samples = 64<br/>value = [40, 24]<br/>class = 0>, fillcolor="#f5cdb0"] ;
# 52 -> 62 ;
# 63 [label=<BP &le; 58.0<br/>gini = 0.465<br/>samples = 19<br/>value = [7, 12]<br/>class = 1>, fillcolor="#acd6f4"] ;
# 62 -> 63 ;
# 64 [label=<BMI &le; 30.05<br/>gini = 0.245<br/>samples = 7<br/>value = [6, 1]<br/>class = 0>, fillcolor="#e9965a"] ;
# 63 -> 64 ;
# 65 [label=<Age &le; 33.5<br/>gini = 0.5<br/>samples = 2<br/>value = [1, 1]<br/>class = 0>, fillcolor="#ffffff"] ;
# 64 -> 65 ;
# 66 [label=<gini = 0.0<br/>samples = 1<br/>value = [1, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 65 -> 66 ;
# 67 [label=<gini = 0.0<br/>samples = 1<br/>value = [0, 1]<br/>class = 1>, fillcolor="#399de5"] ;
# 65 -> 67 ;
# 68 [label=<gini = 0.0<br/>samples = 5<br/>value = [5, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 64 -> 68 ;
# 69 [label=<Pedigree &le; 0.425<br/>gini = 0.153<br/>samples = 12<br/>value = [1, 11]<br/>class = 1>, fillcolor="#4ba6e7"] ;
# 63 -> 69 ;
# 70 [label=<gini = 0.0<br/>samples = 11<br/>value = [0, 11]<br/>class = 1>, fillcolor="#399de5"] ;
# 69 -> 70 ;
# 71 [label=<gini = 0.0<br/>samples = 1<br/>value = [1, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 69 -> 71 ;
# 72 [label=<BMI &le; 43.1<br/>gini = 0.391<br/>samples = 45<br/>value = [33, 12]<br/>class = 0>, fillcolor="#eeaf81"] ;
# 62 -> 72 ;
# 73 [label=<Skin &le; 27.0<br/>gini = 0.337<br/>samples = 42<br/>value = [33, 9]<br/>class = 0>, fillcolor="#eca36f"] ;
# 72 -> 73 ;
# 74 [label=<BP &le; 89.0<br/>gini = 0.461<br/>samples = 25<br/>value = [16, 9]<br/>class = 0>, fillcolor="#f4c8a8"] ;
# 73 -> 74 ;
# 75 [label=<Age &le; 47.0<br/>gini = 0.5<br/>samples = 18<br/>value = [9, 9]<br/>class = 0>, fillcolor="#ffffff"] ;
# 74 -> 75 ;
# 76 [label=<Age &le; 35.0<br/>gini = 0.397<br/>samples = 11<br/>value = [3, 8]<br/>class = 1>, fillcolor="#83c2ef"] ;
# 75 -> 76 ;
# 77 [label=<gini = 0.0<br/>samples = 2<br/>value = [2, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 76 -> 77 ;
# 78 [label=<BP &le; 69.0<br/>gini = 0.198<br/>samples = 9<br/>value = [1, 8]<br/>class = 1>, fillcolor="#52a9e8"] ;
# 76 -> 78 ;
# 79 [label=<gini = 0.0<br/>samples = 1<br/>value = [1, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 78 -> 79 ;
# 80 [label=<gini = 0.0<br/>samples = 8<br/>value = [0, 8]<br/>class = 1>, fillcolor="#399de5"] ;
# 78 -> 80 ;
# 81 [label=<Pregnant &le; 3.5<br/>gini = 0.245<br/>samples = 7<br/>value = [6, 1]<br/>class = 0>, fillcolor="#e9965a"] ;
# 75 -> 81 ;
# 82 [label=<gini = 0.0<br/>samples = 1<br/>value = [0, 1]<br/>class = 1>, fillcolor="#399de5"] ;
# 81 -> 82 ;
# 83 [label=<gini = 0.0<br/>samples = 6<br/>value = [6, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 81 -> 83 ;
# 84 [label=<gini = 0.0<br/>samples = 7<br/>value = [7, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 74 -> 84 ;
# 85 [label=<gini = 0.0<br/>samples = 17<br/>value = [17, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 73 -> 85 ;
# 86 [label=<gini = 0.0<br/>samples = 3<br/>value = [0, 3]<br/>class = 1>, fillcolor="#399de5"] ;
# 72 -> 86 ;
# 87 [label=<Pregnant &le; 8.5<br/>gini = 0.472<br/>samples = 42<br/>value = [16, 26]<br/>class = 1>, fillcolor="#b3d9f5"] ;
# 51 -> 87 ;
# 88 [label=<Glucose &le; 97.0<br/>gini = 0.5<br/>samples = 33<br/>value = [16, 17]<br/>class = 1>, fillcolor="#f3f9fd"] ;
# 87 -> 88 ;
# 89 [label=<gini = 0.0<br/>samples = 5<br/>value = [5, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 88 -> 89 ;
# 90 [label=<BP &le; 87.0<br/>gini = 0.477<br/>samples = 28<br/>value = [11, 17]<br/>class = 1>, fillcolor="#b9dcf6"] ;
# 88 -> 90 ;
# 91 [label=<Glucose &le; 116.5<br/>gini = 0.413<br/>samples = 24<br/>value = [7, 17]<br/>class = 1>, fillcolor="#8bc5f0"] ;
# 90 -> 91 ;
# 92 [label=<Pedigree &le; 1.395<br/>gini = 0.165<br/>samples = 11<br/>value = [1, 10]<br/>class = 1>, fillcolor="#4da7e8"] ;
# 91 -> 92 ;
# 93 [label=<gini = 0.0<br/>samples = 10<br/>value = [0, 10]<br/>class = 1>, fillcolor="#399de5"] ;
# 92 -> 93 ;
# 94 [label=<gini = 0.0<br/>samples = 1<br/>value = [1, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 92 -> 94 ;
# 95 [label=<Insulin &le; 78.0<br/>gini = 0.497<br/>samples = 13<br/>value = [6, 7]<br/>class = 1>, fillcolor="#e3f1fb"] ;
# 91 -> 95 ;
# 96 [label=<gini = 0.0<br/>samples = 3<br/>value = [3, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 95 -> 96 ;
# 97 [label=<Skin &le; 41.5<br/>gini = 0.42<br/>samples = 10<br/>value = [3, 7]<br/>class = 1>, fillcolor="#8ec7f0"] ;
# 95 -> 97 ;
# 98 [label=<gini = 0.0<br/>samples = 7<br/>value = [0, 7]<br/>class = 1>, fillcolor="#399de5"] ;
# 97 -> 98 ;
# 99 [label=<gini = 0.0<br/>samples = 3<br/>value = [3, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 97 -> 99 ;
# 100 [label=<gini = 0.0<br/>samples = 4<br/>value = [4, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 90 -> 100 ;
# 101 [label=<gini = 0.0<br/>samples = 9<br/>value = [0, 9]<br/>class = 1>, fillcolor="#399de5"] ;
# 87 -> 101 ;
# 102 [label=<BMI &le; 27.85<br/>gini = 0.478<br/>samples = 180<br/>value = [71, 109]<br/>class = 1>, fillcolor="#baddf6"] ;
# 0 -> 102 [labeldistance=2.5, labelangle=-45, headlabel="False"] ;
# 103 [label=<Glucose &le; 145.5<br/>gini = 0.375<br/>samples = 36<br/>value = [27, 9]<br/>class = 0>, fillcolor="#eeab7b"] ;
# 102 -> 103 ;
# 104 [label=<Age &le; 59.5<br/>gini = 0.1<br/>samples = 19<br/>value = [18, 1]<br/>class = 0>, fillcolor="#e68844"] ;
# 103 -> 104 ;
# 105 [label=<gini = 0.0<br/>samples = 16<br/>value = [16, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 104 -> 105 ;
# 106 [label=<BMI &le; 25.25<br/>gini = 0.444<br/>samples = 3<br/>value = [2, 1]<br/>class = 0>, fillcolor="#f2c09c"] ;
# 104 -> 106 ;
# 107 [label=<gini = 0.0<br/>samples = 1<br/>value = [0, 1]<br/>class = 1>, fillcolor="#399de5"] ;
# 106 -> 107 ;
# 108 [label=<gini = 0.0<br/>samples = 2<br/>value = [2, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 106 -> 108 ;
# 109 [label=<Pregnant &le; 1.5<br/>gini = 0.498<br/>samples = 17<br/>value = [9, 8]<br/>class = 0>, fillcolor="#fcf1e9"] ;
# 103 -> 109 ;
# 110 [label=<gini = 0.0<br/>samples = 3<br/>value = [3, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 109 -> 110 ;
# 111 [label=<BMI &le; 23.1<br/>gini = 0.49<br/>samples = 14<br/>value = [6, 8]<br/>class = 1>, fillcolor="#cee6f8"] ;
# 109 -> 111 ;
# 112 [label=<gini = 0.0<br/>samples = 2<br/>value = [2, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 111 -> 112 ;
# 113 [label=<BMI &le; 25.8<br/>gini = 0.444<br/>samples = 12<br/>value = [4, 8]<br/>class = 1>, fillcolor="#9ccef2"] ;
# 111 -> 113 ;
# 114 [label=<gini = 0.0<br/>samples = 6<br/>value = [0, 6]<br/>class = 1>, fillcolor="#399de5"] ;
# 113 -> 114 ;
# 115 [label=<Pregnant &le; 4.0<br/>gini = 0.444<br/>samples = 6<br/>value = [4, 2]<br/>class = 0>, fillcolor="#f2c09c"] ;
# 113 -> 115 ;
# 116 [label=<gini = 0.0<br/>samples = 2<br/>value = [0, 2]<br/>class = 1>, fillcolor="#399de5"] ;
# 115 -> 116 ;
# 117 [label=<gini = 0.0<br/>samples = 4<br/>value = [4, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 115 -> 117 ;
# 118 [label=<Glucose &le; 158.5<br/>gini = 0.424<br/>samples = 144<br/>value = [44, 100]<br/>class = 1>, fillcolor="#90c8f0"] ;
# 102 -> 118 ;
# 119 [label=<Age &le; 30.5<br/>gini = 0.487<br/>samples = 88<br/>value = [37, 51]<br/>class = 1>, fillcolor="#c9e4f8"] ;
# 118 -> 119 ;
# 120 [label=<BP &le; 23.0<br/>gini = 0.49<br/>samples = 42<br/>value = [24, 18]<br/>class = 0>, fillcolor="#f8e0ce"] ;
# 119 -> 120 ;
# 121 [label=<gini = 0.0<br/>samples = 4<br/>value = [0, 4]<br/>class = 1>, fillcolor="#399de5"] ;
# 120 -> 121 ;
# 122 [label=<BP &le; 88.0<br/>gini = 0.465<br/>samples = 38<br/>value = [24, 14]<br/>class = 0>, fillcolor="#f4caac"] ;
# 120 -> 122 ;
# 123 [label=<BP &le; 72.0<br/>gini = 0.444<br/>samples = 36<br/>value = [24, 12]<br/>class = 0>, fillcolor="#f2c09c"] ;
# 122 -> 123 ;
# 124 [label=<BMI &le; 33.75<br/>gini = 0.5<br/>samples = 20<br/>value = [10, 10]<br/>class = 0>, fillcolor="#ffffff"] ;
# 123 -> 124 ;
# 125 [label=<BMI &le; 31.05<br/>gini = 0.397<br/>samples = 11<br/>value = [8, 3]<br/>class = 0>, fillcolor="#efb083"] ;
# 124 -> 125 ;
# 126 [label=<Pedigree &le; 0.374<br/>gini = 0.5<br/>samples = 6<br/>value = [3, 3]<br/>class = 0>, fillcolor="#ffffff"] ;
# 125 -> 126 ;
# 127 [label=<gini = 0.0<br/>samples = 2<br/>value = [0, 2]<br/>class = 1>, fillcolor="#399de5"] ;
# 126 -> 127 ;
# 128 [label=<Glucose &le; 136.5<br/>gini = 0.375<br/>samples = 4<br/>value = [3, 1]<br/>class = 0>, fillcolor="#eeab7b"] ;
# 126 -> 128 ;
# 129 [label=<gini = 0.0<br/>samples = 1<br/>value = [0, 1]<br/>class = 1>, fillcolor="#399de5"] ;
# 128 -> 129 ;
# 130 [label=<gini = 0.0<br/>samples = 3<br/>value = [3, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 128 -> 130 ;
# 131 [label=<gini = 0.0<br/>samples = 5<br/>value = [5, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 125 -> 131 ;
# 132 [label=<Pedigree &le; 0.535<br/>gini = 0.346<br/>samples = 9<br/>value = [2, 7]<br/>class = 1>, fillcolor="#72b9ec"] ;
# 124 -> 132 ;
# 133 [label=<gini = 0.0<br/>samples = 6<br/>value = [0, 6]<br/>class = 1>, fillcolor="#399de5"] ;
# 132 -> 133 ;
# 134 [label=<BMI &le; 35.45<br/>gini = 0.444<br/>samples = 3<br/>value = [2, 1]<br/>class = 0>, fillcolor="#f2c09c"] ;
# 132 -> 134 ;
# 135 [label=<gini = 0.0<br/>samples = 1<br/>value = [0, 1]<br/>class = 1>, fillcolor="#399de5"] ;
# 134 -> 135 ;
# 136 [label=<gini = 0.0<br/>samples = 2<br/>value = [2, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 134 -> 136 ;
# 137 [label=<Glucose &le; 157.5<br/>gini = 0.219<br/>samples = 16<br/>value = [14, 2]<br/>class = 0>, fillcolor="#e99355"] ;
# 123 -> 137 ;
# 138 [label=<BMI &le; 43.4<br/>gini = 0.124<br/>samples = 15<br/>value = [14, 1]<br/>class = 0>, fillcolor="#e78a47"] ;
# 137 -> 138 ;
# 139 [label=<gini = 0.0<br/>samples = 13<br/>value = [13, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 138 -> 139 ;
# 140 [label=<Glucose &le; 148.0<br/>gini = 0.5<br/>samples = 2<br/>value = [1, 1]<br/>class = 0>, fillcolor="#ffffff"] ;
# 138 -> 140 ;
# 141 [label=<gini = 0.0<br/>samples = 1<br/>value = [0, 1]<br/>class = 1>, fillcolor="#399de5"] ;
# 140 -> 141 ;
# 142 [label=<gini = 0.0<br/>samples = 1<br/>value = [1, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 140 -> 142 ;
# 143 [label=<gini = 0.0<br/>samples = 1<br/>value = [0, 1]<br/>class = 1>, fillcolor="#399de5"] ;
# 137 -> 143 ;
# 144 [label=<gini = 0.0<br/>samples = 2<br/>value = [0, 2]<br/>class = 1>, fillcolor="#399de5"] ;
# 122 -> 144 ;
# 145 [label=<BMI &le; 34.05<br/>gini = 0.405<br/>samples = 46<br/>value = [13, 33]<br/>class = 1>, fillcolor="#87c4ef"] ;
# 119 -> 145 ;
# 146 [label=<BP &le; 75.0<br/>gini = 0.49<br/>samples = 21<br/>value = [9, 12]<br/>class = 1>, fillcolor="#cee6f8"] ;
# 145 -> 146 ;
# 147 [label=<gini = 0.0<br/>samples = 4<br/>value = [4, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 146 -> 147 ;
# 148 [label=<Glucose &le; 143.0<br/>gini = 0.415<br/>samples = 17<br/>value = [5, 12]<br/>class = 1>, fillcolor="#8bc6f0"] ;
# 146 -> 148 ;
# 149 [label=<Age &le; 47.5<br/>gini = 0.496<br/>samples = 11<br/>value = [5, 6]<br/>class = 1>, fillcolor="#deeffb"] ;
# 148 -> 149 ;
# 150 [label=<BMI &le; 33.0<br/>gini = 0.375<br/>samples = 8<br/>value = [2, 6]<br/>class = 1>, fillcolor="#7bbeee"] ;
# 149 -> 150 ;
# 151 [label=<Insulin &le; 147.5<br/>gini = 0.245<br/>samples = 7<br/>value = [1, 6]<br/>class = 1>, fillcolor="#5aade9"] ;
# 150 -> 151 ;
# 152 [label=<gini = 0.0<br/>samples = 5<br/>value = [0, 5]<br/>class = 1>, fillcolor="#399de5"] ;
# 151 -> 152 ;
# 153 [label=<Pedigree &le; 0.195<br/>gini = 0.5<br/>samples = 2<br/>value = [1, 1]<br/>class = 0>, fillcolor="#ffffff"] ;
# 151 -> 153 ;
# 154 [label=<gini = 0.0<br/>samples = 1<br/>value = [0, 1]<br/>class = 1>, fillcolor="#399de5"] ;
# 153 -> 154 ;
# 155 [label=<gini = 0.0<br/>samples = 1<br/>value = [1, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 153 -> 155 ;
# 156 [label=<gini = 0.0<br/>samples = 1<br/>value = [1, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 150 -> 156 ;
# 157 [label=<gini = 0.0<br/>samples = 3<br/>value = [3, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 149 -> 157 ;
# 158 [label=<gini = 0.0<br/>samples = 6<br/>value = [0, 6]<br/>class = 1>, fillcolor="#399de5"] ;
# 148 -> 158 ;
# 159 [label=<Pedigree &le; 1.088<br/>gini = 0.269<br/>samples = 25<br/>value = [4, 21]<br/>class = 1>, fillcolor="#5fb0ea"] ;
# 145 -> 159 ;
# 160 [label=<Insulin &le; 306.5<br/>gini = 0.172<br/>samples = 21<br/>value = [2, 19]<br/>class = 1>, fillcolor="#4ea7e8"] ;
# 159 -> 160 ;
# 161 [label=<BMI &le; 44.6<br/>gini = 0.1<br/>samples = 19<br/>value = [1, 18]<br/>class = 1>, fillcolor="#44a2e6"] ;
# 160 -> 161 ;
# 162 [label=<gini = 0.0<br/>samples = 16<br/>value = [0, 16]<br/>class = 1>, fillcolor="#399de5"] ;
# 161 -> 162 ;
# 163 [label=<Pregnant &le; 6.0<br/>gini = 0.444<br/>samples = 3<br/>value = [1, 2]<br/>class = 1>, fillcolor="#9ccef2"] ;
# 161 -> 163 ;
# 164 [label=<gini = 0.0<br/>samples = 1<br/>value = [1, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 163 -> 164 ;
# 165 [label=<gini = 0.0<br/>samples = 2<br/>value = [0, 2]<br/>class = 1>, fillcolor="#399de5"] ;
# 163 -> 165 ;
# 166 [label=<Pedigree &le; 0.478<br/>gini = 0.5<br/>samples = 2<br/>value = [1, 1]<br/>class = 0>, fillcolor="#ffffff"] ;
# 160 -> 166 ;
# 167 [label=<gini = 0.0<br/>samples = 1<br/>value = [0, 1]<br/>class = 1>, fillcolor="#399de5"] ;
# 166 -> 167 ;
# 168 [label=<gini = 0.0<br/>samples = 1<br/>value = [1, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 166 -> 168 ;
# 169 [label=<Insulin &le; 147.5<br/>gini = 0.5<br/>samples = 4<br/>value = [2, 2]<br/>class = 0>, fillcolor="#ffffff"] ;
# 159 -> 169 ;
# 170 [label=<gini = 0.0<br/>samples = 2<br/>value = [2, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 169 -> 170 ;
# 171 [label=<gini = 0.0<br/>samples = 2<br/>value = [0, 2]<br/>class = 1>, fillcolor="#399de5"] ;
# 169 -> 171 ;
# 172 [label=<Pedigree &le; 1.157<br/>gini = 0.219<br/>samples = 56<br/>value = [7, 49]<br/>class = 1>, fillcolor="#55abe9"] ;
# 118 -> 172 ;
# 173 [label=<Pedigree &le; 0.343<br/>gini = 0.147<br/>samples = 50<br/>value = [4, 46]<br/>class = 1>, fillcolor="#4aa6e7"] ;
# 172 -> 173 ;
# 174 [label=<Age &le; 48.5<br/>gini = 0.332<br/>samples = 19<br/>value = [4, 15]<br/>class = 1>, fillcolor="#6eb7ec"] ;
# 173 -> 174 ;
# 175 [label=<Glucose &le; 177.0<br/>gini = 0.219<br/>samples = 16<br/>value = [2, 14]<br/>class = 1>, fillcolor="#55abe9"] ;
# 174 -> 175 ;
# 176 [label=<gini = 0.0<br/>samples = 9<br/>value = [0, 9]<br/>class = 1>, fillcolor="#399de5"] ;
# 175 -> 176 ;
# 177 [label=<Glucose &le; 179.5<br/>gini = 0.408<br/>samples = 7<br/>value = [2, 5]<br/>class = 1>, fillcolor="#88c4ef"] ;
# 175 -> 177 ;
# 178 [label=<gini = 0.0<br/>samples = 1<br/>value = [1, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 177 -> 178 ;
# 179 [label=<Glucose &le; 187.5<br/>gini = 0.278<br/>samples = 6<br/>value = [1, 5]<br/>class = 1>, fillcolor="#61b1ea"] ;
# 177 -> 179 ;
# 180 [label=<gini = 0.0<br/>samples = 4<br/>value = [0, 4]<br/>class = 1>, fillcolor="#399de5"] ;
# 179 -> 180 ;
# 181 [label=<Pregnant &le; 4.5<br/>gini = 0.5<br/>samples = 2<br/>value = [1, 1]<br/>class = 0>, fillcolor="#ffffff"] ;
# 179 -> 181 ;
# 182 [label=<gini = 0.0<br/>samples = 1<br/>value = [1, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 181 -> 182 ;
# 183 [label=<gini = 0.0<br/>samples = 1<br/>value = [0, 1]<br/>class = 1>, fillcolor="#399de5"] ;
# 181 -> 183 ;
# 184 [label=<Skin &le; 15.5<br/>gini = 0.444<br/>samples = 3<br/>value = [2, 1]<br/>class = 0>, fillcolor="#f2c09c"] ;
# 174 -> 184 ;
# 185 [label=<gini = 0.0<br/>samples = 1<br/>value = [0, 1]<br/>class = 1>, fillcolor="#399de5"] ;
# 184 -> 185 ;
# 186 [label=<gini = 0.0<br/>samples = 2<br/>value = [2, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 184 -> 186 ;
# 187 [label=<gini = 0.0<br/>samples = 31<br/>value = [0, 31]<br/>class = 1>, fillcolor="#399de5"] ;
# 173 -> 187 ;
# 188 [label=<Pregnant &le; 3.5<br/>gini = 0.5<br/>samples = 6<br/>value = [3, 3]<br/>class = 0>, fillcolor="#ffffff"] ;
# 172 -> 188 ;
# 189 [label=<Pregnant &le; 0.5<br/>gini = 0.375<br/>samples = 4<br/>value = [1, 3]<br/>class = 1>, fillcolor="#7bbeee"] ;
# 188 -> 189 ;
# 190 [label=<gini = 0.0<br/>samples = 1<br/>value = [1, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 189 -> 190 ;
# 191 [label=<gini = 0.0<br/>samples = 3<br/>value = [0, 3]<br/>class = 1>, fillcolor="#399de5"] ;
# 189 -> 191 ;
# 192 [label=<gini = 0.0<br/>samples = 2<br/>value = [2, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 188 -> 192 ;
# }

# %%
graph=pydotplus.graph_from_dot_data(dot_data.getvalue())
graph.write_png("Diabetes.png")
Image(graph.create_png())

# %%
clf=DecisionTreeClassifier(max_depth=3)
clf=clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test,y_pred)*100)
# Out:
# Accuracy: 75.75757575757575

# %%
dot_data=StringIO()
export_graphviz(clf,out_file=dot_data,filled=True,rounded=True,special_characters=True,feature_names=features,class_names=['0','1'])
graph=pydotplus.graph_from_dot_data(dot_data.getvalue())
graph.write_png("Diabetes.png")
Image(graph.create_png())
